# %%
from sklearn.datasets import make_blobs, make_moons
import matplotlib.pyplot as plt
import numpy as np
from scipy.spatial.distance import cdist

# %% [markdown]
# `Задание 1` В данном задании вам необходимо реализовать алгоритм кластеризации k-means

# %%
X, _ = make_blobs(n_samples=1000,
                  centers=2,
                  n_features=2,
                  random_state=42)

# %% [markdown]
# Для домашнего задания возьмем простые данные с двумя признаками, чтобы было проще визуализировать и отлавливать ошибки, но алгоритм задан и для многомерных данных.

# %%
plt.figure(figsize=(9,6))
scatter = plt.scatter(X[:,0], X[:,1])

# %% [markdown]
# Реализуем k-means в виде класса с основными методами fit и predict.
# При инициализации объекта класса `k-means` необходимо задать параметр `k`. Остальное, в приницпе, нам не нужно.
#
# * `fit` должен отыскать корректные центроиды (матрицу размера (k, n_features) и записать их в атрибут `self.centroids`
#
# * `predict` должен уметь предсказать метки для новых данных из того же самого распределения. На вход матрица размера (batch_size, n_features), на выходе - вектор меток

# %%
class KMeans:
    
    def __init__(self, k):
        self.k = k
    
    def fit(self, x):
        # randomly initialize centroids in shape (k, n_features)
        # n_features = x.shape[1]
        self.centroids = None

        done = False
        prev_centroids = None
        while not done:
            # calculate distances for each point to each centroid (you can reuse self.predict for that)
            # find closest centroid to each point
            distances = None
            labels = None
            # for each centroid
            # recalculate centroid as mean of its cluster
            # if prev centroids are same as new centroids: done = True

    def predict(self, x):
        assert len(x.shape) == 2 # it's a batch, not a vector
        # predict a batch of points
        # return vector of labels

# %%
model = KMeans(k=2)
model.fit(X)

y = model.predict(X)

# %%
# Здесь визуализируются ваши кластеры, если всё корректно получилось

plt.figure(figsize=(9,6))
scatter = plt.scatter(X[:,0], X[:,1], c=y)
plt.scatter(model.centroids[:,0], model.centroids[:,1], c='red', label='centroids')
plt.legend();

# %% [markdown]
# `Задание 2` Используя метрику [silhouette score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.silhouette_score.html)
#
# Найдите лучшее k на следующих данных:

# %%
np.random.seed(42)
X, _ = make_blobs(n_samples=1000,
                  centers=10,
                  n_features=2,
                  cluster_std=np.random.uniform(low=0.5, high=2, size=(10)),
                  random_state=42)

# %%
plt.figure(figsize=(9,6))
scatter = plt.scatter(X[:,0], X[:,1])

# %% [markdown]
# И отобразите [silhouette plot](https://www.scikit-yb.org/en/latest/api/cluster/silhouette.html) с помощью библиотеки

# %% [markdown]
# `Задание 3` Используя готовый алгоритм DBSCAN, кластеризуйте данные и отобразите на графике каждый кластер соответствующим цветом

# %%
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_blobs, make_moons

import matplotlib.pyplot as plt
import numpy as np

# %%
X, _ = make_moons(n_samples=100)

# %%
plt.figure(figsize=(9,6))
scatter = plt.scatter(X[:,0], X[:,1])

# %%
np.random.seed(42)
X, _ = make_blobs(n_samples=1000,
                  centers=15,
                  n_features=2,
                  cluster_std=np.random.uniform(low=0.5, high=1.2, size=(15)),
                  random_state=42)

# %% [markdown]
# `Задание 4` Изучите [метод](https://stats.stackexchange.com/questions/406587/determining-epsilon-for-dbscan) (ещё [тут](https://machinelearningknowledge.ai/tutorial-for-dbscan-clustering-in-python-sklearn/)) подбора гиперпараметра `eps` для DBSCAN, который называется "локтевой метод" и реализуйте его для подбора оптимального параметра на данном датасете:
#
# Визуализируйте результаты

# %%
plt.figure(figsize=(9,6))
scatter = plt.scatter(X[:,0], X[:,1])
